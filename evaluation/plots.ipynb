# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = np.load('/home/oliverkn/pro/results/4_4/alad/5/evaluation/metrics.npy', allow_pickle=True).item()
metrics2 = np.load('/home/oliverkn/pro/results/4_4/alad/8/metrics.npy', allow_pickle=True).item()
metrics2 = metrics

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(metrics['epoch'],metrics['auc'], label='auroc')
ax.plot(metrics2['epoch'],metrics2['auc'], label='auroc2')
ax.set_title('Training metrics')
ax.set_xlabel('Epoch')
ax.legend()

# %%
epoch = 0

fig, ax = plt.subplots(figsize=(10,8))
ax.plot(metrics['roc'][epoch][0],metrics['roc'][epoch][1])
ax.set_title('ROC (epoch %s)'%epoch)
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')

print('AUROC=%s'%metrics['auc'][epoch])
# Out:
# AUROC=0.7296016190085618
