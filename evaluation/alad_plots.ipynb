# %%
from importlib import reload
from evaluation import alad_plot_utils 
reload(alad_plot_utils)

plotter = alad_plot_utils.AladPlotter()

# %%
data_path = '/home/oliverkn/pro/data/hlf_set_new'
plotter.load_data(data_path)

# %%
result_path = '/home/oliverkn/pro/results/4_4/alad/test_datanew/'
result_path = '/home/oliverkn/euler/results/hlf_set/alad/2_l21/'
weights_file = result_path + 'model-17000000'
plotter.load_alad(result_path, weights_file)

# %%
plotter.plot_roc()
# Out:
# /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
score_type = 'fm'
plotter.plot_anomaly_scores(score_type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1689ea97bb13> in <module>
#       1 score_type = 'fm'
# ----> 2 plotter.plot_anomaly_scores(score_type)
#
# ~/cloud/eth/2019_FS/pro/pycharm/evaluation/alad_plot_utils.py in plot_anomaly_scores(self, score_type)
#     122         for dataset in dataset_list:
#     123             x, _ = load_data(self.data_path, set='valid', type='custom', shuffle=True, sm_list=[dataset], bsm_list=[],
# --> 124                              balance_sm=False)
#     125             x = x[:max_samples]
#     126             x = self.preprocessor.transform(x)
#
# TypeError: load_data() got an unexpected keyword argument 'type'
