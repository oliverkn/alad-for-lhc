# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = np.load('/home/oliverkn/pro/results/1/metrics.npy', allow_pickle=True).item()

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(metrics['epoch'],metrics['acc'], label='accuarcy')
ax.plot(metrics['epoch'],metrics['loss'], label='loss')
ax.plot(metrics['epoch'],metrics['auc'], label='auroc')
ax.set_title('Training metrics')
ax.set_xlabel('Epoch')
ax.legend()

# %%
epoch = 25

fig, ax = plt.subplots(figsize=(10,8))
ax.loglog(metrics['roc'][epoch][0],metrics['roc'][epoch][1])
ax.set_title('ROC (epoch %s)'%epoch)
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')

print('AUROC=%s'%metrics['auc'][epoch])
# Out:
# AUROC=0.8869795249655734
