# %%
from importlib import reload
from alad_mod import alad_plot_utils 
reload(alad_plot_utils)

plotter = alad_plot_utils.AladPlotter()

# %%
data_path = '/home/oliverkn/pro/data/hlf_set'
bsm_list = ['Ato4l', 'leptoquark', 'hToTauTau', 'hChToTauNu']
plotter.load_data(data_path, bsm_list)

# %%
result_path = '/home/oliverkn/pro/results/4_4/alad/test_eval_6/'
weights_file = result_path + 'model-900000'
plotter.load_alad(result_path, weights_file)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0827 14:06:09.987689 140347453445952 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0827 14:06:09.988995 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad_plot_utils.py:55: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0827 14:06:09.989459 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad_plot_utils.py:56: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0827 14:06:10.036073 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:29: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0827 14:06:10.039020 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:44: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0827 14:06:10.042416 140347453445952 deprecation.py:323] From /home/oliverkn/pro/results/4_4/alad/test_eval_6/config.py:76: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0827 14:06:10.442981 140347453445952 deprecation.py:323] From /home/oliverkn/pro/results/4_4/alad/test_eval_6/config.py:186: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# W0827 14:06:10.552325 140347453445952 deprecation.py:323] From /home/oliverkn/pro/results/4_4/alad/test_eval_6/config.py:194: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W0827 14:06:10.869813 140347453445952 deprecation.py:323] From /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0827 14:06:10.949811 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:126: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0827 14:06:10.950610 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:143: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0827 14:06:13.217700 140347453445952 deprecation.py:323] From /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/tensorflow/python/training/moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0827 14:06:13.913982 140347453445952 deprecation.py:323] From /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0827 14:06:14.111926 140347453445952 deprecation.py:506] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:214: calling norm (from tensorflow.python.ops.linalg_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0827 14:06:14.149160 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:243: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0827 14:06:14.159372 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:258: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0827 14:06:14.161595 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:260: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0827 14:06:14.162898 140347453445952 deprecation_wrapper.py:119] From /home/oliverkn/cloud/eth/2019_FS/pro/pycharm/alad_mod/alad.py:397: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0827 14:06:14.271343 140347453445952 deprecation.py:323] From /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
plotter.plot_roc()
# Out:
# data shape:(1426322, 21)
# data shape:(1384905, 21)
# data shape:(1242030, 21)
# data shape:(1238490, 21)
# /home/oliverkn/pro/pycharm/venv/lib/python3.6/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plotter.plot_anomaly_scores()
